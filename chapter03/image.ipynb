# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
)

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": "https://images.unsplash.com/photo-1736264335247-8ec5664c8328?q=80&w=1887&auto=format&fit=crop&ixlib=rb4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D"
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# 이 사진에는 검은색 운동복을 입은 한 여성이 부엌에서 요리 준비를 하고 있습니다. 그녀는 푸른색 그릇에 있는 달걀을 거품기로 휘저으며 웃고 있습니다. 뒤에는 팬에 베이컨 같은 재료가 조리되고 있습니다. 그녀는 즐거운 분위기에서 요리하는 모습을 보여줍니다.

# %%
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# 내 컴퓨터의 이미지 경로 지정
image_path = "./data/images/mangwon_bakery.jpg"
base64_image = encode_image(image_path)

# %%
messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "이 이미지에 대해 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    # f-string을 이용하여 base64 데이터를 주입합니다.
                    "url": f"data:image/jpeg;base64,{base64_image}",
                },
            },
        ],
    }
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# 이미지는 "UGLY BAKERY"라는 베이커리에 있는 진열대를 보여줍니다. 진열대에는 다양한 빵들이 진열되어 있으며, 각 빵 앞에는 작은 카드가 있어 빵의 이름과 가격이 적혀 있습니다. 상단에는 크림과 재료가 샌드위치처럼 들어 있는 빵들이 있고, 하단에는 다양한 종류의 빵들이 겹겹이 쌓여 있습니다. 빵은 다양한 재료와 맛으로 구성되어 있어, 시각적으로도 다채롭습니다.

# %%
seolleung_terrarosa_base64 = encode_image("./data/images/seolleung_terrarosa.jpg")
local_stitch_terrarosa_base64 = encode_image("./data/images/local_stitch_terrarosa.jpg")

messages = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "두 카페의 차이점을 설명해주세요."},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{seolleung_terrarosa_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{local_stitch_terrarosa_base64}",
                },
            },
        ],
    }
]
response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)
response.choices[0].message.content
# Out:
# '첫 번째 카페와 두 번째 카페는 다음과 같은 차이점이 있습니다:\n\n1. **인테리어 스타일**:\n   - 첫 번째 카페는 더 어두운 톤과 나무 바닥을 사용해 고급스럽고 따뜻한 느낌을 줍니다.\n   - 두 번째 카페는 밝은 색상과 현대적인 디자인으로 밝고 통풍이 잘 되는 분위기를 연출합니다.\n\n2. **조명**:\n   - 첫 번째 카페는 천장에 많은 작은 조명들이 있어 부드러운 조명을 제공합니다.\n   - 두 번째 카페는 전체적으로 밝고 넓게 조명된 환경입니다.\n\n3. **공간 구성**:\n   - 첫 번째 카페는 좌석이 많이 모여 있어 사교적인 분위기를 조성합니다.\n   - 두 번째 카페는 넓고 개방된 공간으로 개인적인 대화나 작업이 가능한 환경입니다.\n\n4. **색상**:\n   - 첫 번째 카페는 어두운 색조의 내부 디자인을 가지고 있습니다.\n   - 두 번째 카페는 노란색과 흰색을 주로 사용해 명랑한 느낌을 줍니다.\n\n이러한 차이점들은 각 카페의 분위기와 방문 목적에 따라 선택할 수 있도록 합니다.'

# %%
oecd_rnd_2021_base64 = encode_image("./data/images/oecd_rnd_2021_small.png")
oecd_rnd_2022_base64 = encode_image("./data/images/oecd_rnd_2022_large.png")

messages_large = [
    {
        "role": "user",
        "content": [
            {"type": "text", "text": "첫번째는 2021년 데이터이고, 두번째는 2022년 데이터입니다. 이 데이터에 대해 설명해주세요. 어떤변화가 있었나요?"},
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{oecd_rnd_2021_base64}",
                },
            },
            {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{oecd_rnd_2022_base64}",
                },
            },
        ],
    }
]

response_large = client.chat.completions.create(
    model="gpt-4o",
    messages=messages_large
)
print(response_large.choices[0].message.content)

response_large = client.chat.completions.create(
    model="gpt-4o",
    messages=messages_large
)
print(response_large.choices[0].message.content)
# Out:
# 첫 번째 그래프는 2021년 데이터, 두 번째 그래프는 2022년 데이터를 나타냅니다. 각각의 데이터는 각국의 연구개발비 규모와 GDP 대비 연구개발비 비중을 보여줍니다. 주요 변화를 요약하면 다음과 같습니다:
#
# 1. **연구개발비 변화:**
#    - 미국: 2021년 720,880백만 달러에서 2022년 806,013백만 달러로 증가
#    - 중국: 2021년 353,484백만 달러에서 2022년 433,500백만 달러로 증가
#    - 한국: 2021년 89,282백만 달러에서 2022년 91,013백만 달러로 증가
#
# 2. **GDP 대비 연구개발비 비중 변화:**
#    - 스위스: 5.44%에서 5.56%로 증가, 가장 높은 비중 유지
#    - 이스라엘: 4.93%에서 5.21%로 증가
#    - 한국: 4.93%에서 4.91%로 약간 감소
#
# 이 데이터는 각국의 연구개발 투자 규모와 경제에서 해당 투자의 상대적인 중요성에 대한 정보를 제공합니다. 전반적으로 주요국의 연구개발비는 증가하는 경향을 보이며, 특히 미국과 중국의 경우 규모가 크게 늘었습니다.
# 두 이미지는 2021년과 2022년의 연구 개발비(R&D) 지출 및 GDP 대비 연구 개발비 비중을 보여줍니다. 각 나라의 자료는 OECD의 과학 및 기술 지표를 기준으로 합니다.
#
# **변화 요약**:
# 1. **연구 개발비 증감**:
#    - 미국의 R&D 지출이 증가했습니다. 2021년 720,880백만 USD에서 2022년 806,013백만 USD로 증가했습니다.
#    - 중국과 일본의 R&D 지출도 소폭 증가했습니다.
#    - 한국의 연구 개발비 역시 91,013백만 USD로 증가했습니다.
#
# 2. **GDP 대비 R&D 비중 변화**:
#    - 미국은 3.45%에서 3.46%로, 한국은 4.93%에서 5.21%로 비중이 증가했습니다.
# ...
