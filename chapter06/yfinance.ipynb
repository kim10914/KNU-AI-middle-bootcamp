# %%
import yfinance as yf

msft = yf.Ticker("MSFT") #Microsoft 객체 생성

display(msft.info) # Ticker 객체에 대한 정보 출력
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
hist = msft.history(period="5d") # 최근 5일간의 주가 데이터 가져오기
display(hist) # 최근 5일간의 주가 데이터 출력

# 아마존 : AMZN
# 구글 : GOOGL
# 삼성전자 : 005930.KQ
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-06-22 00:00:00-04:00  375.739990  381.630005  367.070007  367.339996
# 2026-06-23 00:00:00-04:00  372.380005  377.220001  370.670013  373.940002
# 2026-06-24 00:00:00-04:00  371.570007  378.880005  364.779999  365.459991
# 2026-06-25 00:00:00-04:00  362.769989  364.230011  349.200012  352.829987
# 2026-06-26 00:00:00-04:00  357.149994  376.609985  355.429993  372.970001
#
#                               Volume  Dividends  Stock Splits
# Date
# 2026-06-22 00:00:00-04:00   45171100        0.0           0.0
# 2026-06-23 00:00:00-04:00   40647600        0.0           0.0
# 2026-06-24 00:00:00-04:00   44509900        0.0           0.0
# 2026-06-25 00:00:00-04:00   66179000        0.0           0.0
# 2026-06-26 00:00:00-04:00  186112200        0.0           0.0

# %%
msft.recommendations # 주식 종목의 추천 여부 보기
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         13   40     3     0           0
# 1    -1m         12   40     3     0           0
# 2    -2m          9   42     3     0           0
# 3    -3m         10   45     3     0           0
