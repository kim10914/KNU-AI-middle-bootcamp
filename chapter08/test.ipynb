# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

model = ChatOpenAI(
    model="openai/gpt-4o-mini",        # OpenRouter는 "제공자/모델" 형식
    api_key=OPENAI_API_KEY,
    base_url="https://openrouter.ai/api/v1",
)
model.invoke("최근 로제가 발표한 신곡은 무엇인가요?")
# Out:
# AIMessage(content='제 정보는 2023년 10월까지 업데이트되어 있으며, 그 이후의 신곡에 대한 정보는 포함되어 있지 않습니다. 로제가 발표한 가장 최근의 곡은 2021년의 "On The Ground"와 "GONE"이었습니다. 최신 소식을 확인하시려면 공식 소셜 미디어 채널이나 음악 관련 뉴스 웹사이트를 방문해보시는 것이 좋습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 19, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': None, 'image_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'cache_write_tokens': 0, 'video_tokens': 0}, 'cost': 5.505e-05, 'is_byok': False, 'cost_details': {'upstream_inference_cost': 5.505e-05, 'upstream_inference_prompt_cost': 2.85e-06, 'upstream_inference_completions_cost': 5.22e-05}}, 'model_provider': 'openai', 'model_name': 'openai/gpt-4o-mini', 'system_fingerprint': 'fp_59e007eafa', 'id': 'gen-1782786968-i9uvsIQeYGP3xlvFTxlN', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f1662-5c35-7f70-b4aa-c5337934f744-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 87, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search = DuckDuckGoSearchResults(results_separator=";\n" )
docs = search.invoke("최근 로제가 발표한 신곡은 무엇인가요?")

print(docs)
# Out:
# C:\Users\kim10\AppData\Local\Temp\ipykernel_16000\2566318881.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchResults
# snippet: 2 weeks ago - 로제(본명: 박채영, 영어: Roseanne Park 로젠 박[*] MBE, 1997년 2월 11일~)는 대한민국과 뉴질랜드의 가수, 댄서이자 걸그룹 BLACKPINK의 멤버이다. 1997년 뉴질랜드 오클랜드에서 태어났고 만 7살 때부터 오스트레일리아 빅토리아주 ..., title: 로제 (가수) - 위키백과, 우리 모두의 백과사전, link: https://ko.wikipedia.org/wiki/로제_(가수);
# snippet: 3 days ago - 멕시코 최대 음원 차트에 46위로 진입하였다. 이 차트에 이름을 올린 한국 가수는 방탄소년단, BLACKPINK가 유일했으며, KPOP 솔로 가수로 이름을 올린 건 로제가 최초이다., title: 로제(BLACKPINK) - 나무위키, link: https://namu.wiki/w/로제(BLACKPINK);
# snippet: 2 weeks ago - 워너비엔터테인먼트에서 VVS 이후 2년 만에 선보이는 보이그룹 EION이 데뷔할 예정이다. BLACKPINK의 멤버 로제가 첫 번째 디럭스 앨범 《로제(BLACKPINK)/디럭스 앨범》을 발매할 예정이다., title: 2026년 가요계 - 나무위키, link: https://namu.wiki/w/2026년+가요계;
# snippet: December 8, 2025 - 로제가 첫 솔로 정규 앨범 를 발매한 지 벌써 1년이 지났습니다., title: 로제의 첫 솔로 앨범 1주년 기념, 그래미 뮤지엄 무대 | 보그 코리아 (Vogue Korea), link: https://www.vogue.co.kr/2025/12/08/로제의-첫-솔로-앨범-1주년-기념-그래미-뮤지엄-무대
